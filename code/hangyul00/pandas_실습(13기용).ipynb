# %% [markdown]
# # 1. 데이터프레임 만들기

# %% [markdown]
# ### 1-1) 직접 import를 사용해서 pandas를 실행해보세요 (약자를 pd로 설정해주세요)

# %% [markdown]
# #### - 판다스 실행하기

# %%
import pandas as pd

# %% [markdown]
# ### 1-2) 실습 파일을 불러와 'df'라는 이름으로 데이터프레임을 만들어주세요

# %% [markdown]
# #### - 'insight 중고차 정보.csv' 파일 불러오기

# %%
df = pd.read_csv('./insight 중고차 정보.csv')

# %%
#데이터프레임 확인하기
df
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 0   s1  400.0   25.0  sedan  수원  배승식
# 1   s2  480.0   24.0  sedan  서울  이주성
# 2   v1  465.0   24.0    suv  화성  김민희
# 3   c1  340.0   19.0  coupe  서울  김주희
# 4   c2    NaN    NaN  coupe  수원  이수연
# 5   v2    NaN   29.0    suv  광주  황현정
# 6   s3  490.0   26.0  sedan  고양  신현지
# 7   v3  400.0    NaN    suv  광주  최가은
# 8   s4  390.0   21.0  sedan  서울  이수빈

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:16f19cef-ed1d-42bd-a173-6ad8ba6c7393.png)

# %% [markdown]
# ### 1-3) 다음의 리스트를 활용하여 직접 데이터프레임을 구성해보세요

# %% [markdown]
# #### 1. 사용할 리스트

# %%
customer_id = ['s1', 's2', 'v1', 'c1', 'c2', 'v2', 's3', 'v3', 's4']
total_km = [400, 480, 465, 340, None, None, 490, 400, 390]
fuel = [25, 24, 24, 19, None, 29, 26, None, 21]
car = ['sedan', 'sedan', 'suv', 'coupe', 'coupe', 'suv', 'sedan', 'suv', 'sedan']
local = ['수원', '서울', '화성', '서울', '수원', '광주', '고양', '광주', '서울']
owner = ['배승식', '이주성', '김민희', '김주희', '이수연', '황현정', '신현지', '최가은', '이수빈']

# %% [markdown]
# #### 2. data 딕셔너리를 사용해서 df에 데이터프레임 생성하기

# %%
data={'고객ID' : ['s1', 's2', 'v1', 'c1', 'c2', 'v2', 's3', 'v3', 's4'], '주행거리' : [400, 480, 465, 340, None, None, 490, 400, 390], '연료사용량' : [25, 24, 24, 19, None, 29, 26, None, 21], '차종' : ['sedan', 'sedan', 'suv', 'coupe', 'coupe', 'suv', 'sedan', 'suv', 'sedan'], '지역' : ['수원', '서울', '화성', '서울', '수원', '광주', '고양', '광주', '서울'], '차주' : ['배승식', '이주성', '김민희', '김주희', '이수연', '황현정', '신현지', '최가은', '이수빈']
    #['고객ID', '주행거리', '연료사용량', '차종', '지역', '차주']를 컬럼 이름으로 딕셔너리 구성
    
}

columns= [] #생략 가능 

df = pd.DataFrame(data)

# %%
#데이터프레임 확인하기
df
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 0   s1  400.0   25.0  sedan  수원  배승식
# 1   s2  480.0   24.0  sedan  서울  이주성
# 2   v1  465.0   24.0    suv  화성  김민희
# 3   c1  340.0   19.0  coupe  서울  김주희
# 4   c2    NaN    NaN  coupe  수원  이수연
# 5   v2    NaN   29.0    suv  광주  황현정
# 6   s3  490.0   26.0  sedan  고양  신현지
# 7   v3  400.0    NaN    suv  광주  최가은
# 8   s4  390.0   21.0  sedan  서울  이수빈

# %% [markdown]
# 처음 불러온 데이터프레임과 같은 형태라면 정답입니다!

# %% [markdown]
# # 2. 데이터 확인하기

# %% [markdown]
# ### 2-1) 데이터프레임의 기본 정보를 확인해주세요

# %% [markdown]
# #### 1. head를 사용하여 앞에서 3번째 값까지 확인

# %%
df.head(3)
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 0   s1  400.0   25.0  sedan  수원  배승식
# 1   s2  480.0   24.0  sedan  서울  이주성
# 2   v1  465.0   24.0    suv  화성  김민희

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:36825299-460e-431b-b8b7-1ffcad4e070a.png)

# %% [markdown]
# #### 2. tail을 사용하여 마지막에서 4번째 값까지 확인

# %%
df.tail(4)
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 5   v2    NaN   29.0    suv  광주  황현정
# 6   s3  490.0   26.0  sedan  고양  신현지
# 7   v3  400.0    NaN    suv  광주  최가은
# 8   s4  390.0   21.0  sedan  서울  이수빈

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:27a67cf0-ed66-4af2-a892-71b7e97d39dc.png)

# %% [markdown]
# #### 3. isnull을 사용하여 컬럼 별로 결측치 확인

# %%
df.isnull()
# Out:
#     고객ID   주행거리  연료사용량     차종     지역     차주
# 0  False  False  False  False  False  False
# 1  False  False  False  False  False  False
# 2  False  False  False  False  False  False
# 3  False  False  False  False  False  False
# 4  False   True   True  False  False  False
# 5  False   True  False  False  False  False
# 6  False  False  False  False  False  False
# 7  False  False   True  False  False  False
# 8  False  False  False  False  False  False

# %% [markdown]
# 아래 그림처럼 나오면 됩니다. (True값이 결측치임을 의미합니다.)
#
# ![image.png](attachment:1ee1bd39-d3ea-4ee2-a1b9-4625d1299fd1.png)

# %% [markdown]
# #### 4. info를 사용하여 컬럼 별 특성 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   고객ID    9 non-null      object
#  1   주행거리    7 non-null      float64
#  2   연료사용량   7 non-null      float64
#  3   차종      9 non-null      object
#  4   지역      9 non-null      object
#  5   차주      9 non-null      object
# dtypes: float64(2), object(4)
# memory usage: 564.0+ bytes

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:4851d04e-e9dc-457a-b30f-dca922313910.png)

# %% [markdown]
# #### 5. value_counts를 사용하여 지역 열의 데이터 종류 및 개수 확인

# %%
df.value_counts('지역')
# Out:
# 지역
# 서울    3
# 광주    2
# 수원    2
# 고양    1
# 화성    1
# Name: count, dtype: int64

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:75930818-63ff-4e69-ba6a-4900124237f9.png)

# %% [markdown]
# # 3. 데이터 추출하기

# %% [markdown]
# ### 3-1) 다양한 인덱싱 방법을 사용해 요구하는 데이터를 반환해주세요

# %% [markdown]
# #### 1. 컬럼명을 사용하여 6번째 차주를 반환

# %%
df.loc[5, '차주']
# Out:
# '황현정'

# %% [markdown]
# '황현정'이 나오면 정답!

# %% [markdown]
# #### 2. 컬럼 명을 사용하여 4번째 차종을 반환

# %%
df.loc[3, '차종']
# Out:
# 'coupe'

# %% [markdown]
# 'coupe'가 나오면 정답!

# %% [markdown]
# #### 3. loc를 사용하여 3번 인덱스의 차종 반환

# %%
df.loc[3, '차종']
# Out:
# 'coupe'

# %% [markdown]
# 'coupe'가 나오면 정답!

# %% [markdown]
# #### 4. loc를 사용하여 2번 인덱스의 지역 반환

# %%
df.loc[2, '지역']
# Out:
# '화성'

# %% [markdown]
# '화성'이 나오면 정답!

# %% [markdown]
# #### 5. iloc를 사용하여 5번째 고객ID 반환

# %%
df.iloc[4,0]
# Out:
# 'c2'

# %% [markdown]
# 'c2'가 나오면 정답!

# %% [markdown]
# #### 6. iloc를 사용하여 5번째 차주 반환

# %%
df.iloc[4,5]
# Out:
# '이수연'

# %% [markdown]
# '이수연'이 나오면 정답!

# %% [markdown]
# #### 7. iloc을 사용하여 마지막 행 반환 (Series 타입으로 출력)

# %%
df.iloc[8, 0:]
# Out:
# 고객ID        s4
# 주행거리     390.0
# 연료사용량     21.0
# 차종       sedan
# 지역          서울
# 차주         이수빈
# Name: 8, dtype: object

# %% [markdown]
# #### 8. 차주 컬럼을 반환 (Series 타입으로 출력)

# %%
df.iloc[ :, 5]
# Out:
# 0    배승식
# 1    이주성
# 2    김민희
# 3    김주희
# 4    이수연
# 5    황현정
# 6    신현지
# 7    최가은
# 8    이수빈
# Name: 차주, dtype: object

# %% [markdown]
# ### 3-2) 이번엔 슬라이싱을 사용하여 요구하는 데이터를 반환해주세요

# %% [markdown]
# #### 1. 인덱스로 2~4번째 데이터 슬라이싱

# %%
df.iloc[1:4]
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 1   s2  480.0   24.0  sedan  서울  이주성
# 2   v1  465.0   24.0    suv  화성  김민희
# 3   c1  340.0   19.0  coupe  서울  김주희

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:f2bf3d38-cddb-4df4-a21f-88dbfb24a37d.png)

# %% [markdown]
# #### 2. loc를 사용하여 차종-차주의 4~7번째 데이터 슬라이싱

# %%
df.loc[[3,4,5,6],['차종', '지역', '차주']]
# Out:
#       차종  지역   차주
# 3  coupe  서울  김주희
# 4  coupe  수원  이수연
# 5    suv  광주  황현정
# 6  sedan  고양  신현지

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:d435c634-d1fb-4e64-bf0f-519944647af4.png)

# %% [markdown]
# #### 3. iloc를 사용하여 차종-차주의 4~7번째 데이터 슬라이싱

# %%
df.iloc[3:7, 3:6]
# Out:
#       차종  지역   차주
# 3  coupe  서울  김주희
# 4  coupe  수원  이수연
# 5    suv  광주  황현정
# 6  sedan  고양  신현지

# %% [markdown]
# 방금 전과 같은 결과가 출력되면 됩니다.

# %% [markdown]
# ### 3-3) 불리언 인덱싱을 통해 원하는 데이터를 추출해주세요

# %% [markdown]
# #### 1. 지역이 서울인 행을 모두 반환

# %%
cond = df['지역']=='서울'
df[cond]
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 1   s2  480.0   24.0  sedan  서울  이주성
# 3   c1  340.0   19.0  coupe  서울  김주희
# 8   s4  390.0   21.0  sedan  서울  이수빈

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:a3f364a6-b6c1-452f-bb63-4edb35909c4e.png)

# %% [markdown]
# #### 2. 주행거리가 400 이상인 행을 모두 반환

# %%
cond = df['주행거리'] >=400
df[cond]
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 0   s1  400.0   25.0  sedan  수원  배승식
# 1   s2  480.0   24.0  sedan  서울  이주성
# 2   v1  465.0   24.0    suv  화성  김민희
# 6   s3  490.0   26.0  sedan  고양  신현지
# 7   v3  400.0    NaN    suv  광주  최가은

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:f3d69189-7096-46a6-876e-d1796e9bde8d.png)

# %% [markdown]
# #### 3. 지역이 서울이고, 주행거리가 400 이상인 행을 반환

# %%
cond =(df['지역']== '서울') & (df['주행거리']>=400)
df[cond]
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 1   s2  480.0   24.0  sedan  서울  이주성

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:0e251688-5fe2-4138-a4d5-837ad3d3cc75.png)

# %% [markdown]
# ### 3-4) 인덱스를 여러 방식으로 재설정해주세요

# %% [markdown]
# #### 1. reindex를 사용하여 인덱스가 8부터 시작하는 내림차순 df2 생성

# %%
df2 = df.reindex([8,7,6,5,4,3,2,1,0])

# %%
# 데이터프레임 확인
df2
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 8   s4  390.0   21.0  sedan  서울  이수빈
# 7   v3  400.0    NaN    suv  광주  최가은
# 6   s3  490.0   26.0  sedan  고양  신현지
# 5   v2    NaN   29.0    suv  광주  황현정
# 4   c2    NaN    NaN  coupe  수원  이수연
# 3   c1  340.0   19.0  coupe  서울  김주희
# 2   v1  465.0   24.0    suv  화성  김민희
# 1   s2  480.0   24.0  sedan  서울  이주성
# 0   s1  400.0   25.0  sedan  수원  배승식

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:13dd6e06-444f-4b36-85c2-f9e05a80a8f7.png)

# %% [markdown]
# #### 2. df2를 다시 0부터 시작하는 오름차순 인덱스로 돌려놓되, 값들이 인덱스를 따라가지 않도록 주의 (Hint : .index = )

# %%
df2 = df.reindex([8,7,6,5,4,3,2,1,0])
df2.index = [0,1,2,3,4,5,6,7,8]

# %%
# 데이터프레임 확인
df2
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 0   s4  390.0   21.0  sedan  서울  이수빈
# 1   v3  400.0    NaN    suv  광주  최가은
# 2   s3  490.0   26.0  sedan  고양  신현지
# 3   v2    NaN   29.0    suv  광주  황현정
# 4   c2    NaN    NaN  coupe  수원  이수연
# 5   c1  340.0   19.0  coupe  서울  김주희
# 6   v1  465.0   24.0    suv  화성  김민희
# 7   s2  480.0   24.0  sedan  서울  이주성
# 8   s1  400.0   25.0  sedan  수원  배승식

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:d0e94c87-798d-49a5-8243-f2ec61c04a6d.png)

# %% [markdown]
# #### 3. set_index를 사용해서 df로부터 고객ID를 인덱스로 하는 df3 생성

# %%
df3 = df.set_index('고객ID')

# %%
# 데이터프레임 확인
df3
# Out:
#        주행거리  연료사용량     차종  지역   차주
# 고객ID
# s1    400.0   25.0  sedan  수원  배승식
# s2    480.0   24.0  sedan  서울  이주성
# v1    465.0   24.0    suv  화성  김민희
# c1    340.0   19.0  coupe  서울  김주희
# c2      NaN    NaN  coupe  수원  이수연
# v2      NaN   29.0    suv  광주  황현정
# s3    490.0   26.0  sedan  고양  신현지
# v3    400.0    NaN    suv  광주  최가은
# s4    390.0   21.0  sedan  서울  이수빈

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:41cd9dde-7faa-4a82-a82b-52ddd6c4aa60.png)

# %% [markdown]
# # 4. 데이터 조작하기

# %% [markdown]
# ### 4-1) 데이터를 추가하고 삭제해주세요

# %% [markdown]
# #### 1. 연비를 나타내는 '연비' 컬럼 추가 (계산식 : 주행거리 / 연료사용량)

# %%
# 연비 = 주행거리/연료사용량
df['연비']=df['주행거리']/df['연료사용량']

# %%
# 데이터프레임 확인
df
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주         연비
# 0   s1  400.0   25.0  sedan  수원  배승식  16.000000
# 1   s2  480.0   24.0  sedan  서울  이주성  20.000000
# 2   v1  465.0   24.0    suv  화성  김민희  19.375000
# 3   c1  340.0   19.0  coupe  서울  김주희  17.894737
# 4   c2    NaN    NaN  coupe  수원  이수연        NaN
# 5   v2    NaN   29.0    suv  광주  황현정        NaN
# 6   s3  490.0   26.0  sedan  고양  신현지  18.846154
# 7   v3  400.0    NaN    suv  광주  최가은        NaN
# 8   s4  390.0   21.0  sedan  서울  이수빈  18.571429

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:e7db3c5a-15eb-4268-90cd-5bf7352ef910.png)

# %% [markdown]
# #### 2. drop을 사용하여 연료사용량 컬럼을 삭제

# %%
# axis=1, inplace=True 로 설정해주세요
df.drop('연료사용량',axis=1)
# Out:
#   고객ID   주행거리     차종  지역   차주         연비
# 0   s1  400.0  sedan  수원  배승식  16.000000
# 1   s2  480.0  sedan  서울  이주성  20.000000
# 2   v1  465.0    suv  화성  김민희  19.375000
# 3   c1  340.0  coupe  서울  김주희  17.894737
# 4   c2    NaN  coupe  수원  이수연        NaN
# 5   v2    NaN    suv  광주  황현정        NaN
# 6   s3  490.0  sedan  고양  신현지  18.846154
# 7   v3  400.0    suv  광주  최가은        NaN
# 8   s4  390.0  sedan  서울  이수빈  18.571429

# %%
# 데이터프레임 확인
df
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주         연비
# 0   s1  400.0   25.0  sedan  수원  배승식  16.000000
# 1   s2  480.0   24.0  sedan  서울  이주성  20.000000
# 2   v1  465.0   24.0    suv  화성  김민희  19.375000
# 3   c1  340.0   19.0  coupe  서울  김주희  17.894737
# 4   c2    NaN    NaN  coupe  수원  이수연        NaN
# 5   v2    NaN   29.0    suv  광주  황현정        NaN
# 6   s3  490.0   26.0  sedan  고양  신현지  18.846154
# 7   v3  400.0    NaN    suv  광주  최가은        NaN
# 8   s4  390.0   21.0  sedan  서울  이수빈  18.571429

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:44c521ce-b179-4477-89b2-239c50130b70.png)

# %% [markdown]
# ### 4-2) 데이터의 Nan 값을 0으로 변환하고 타입도 바꿔주세요

# %% [markdown]
# #### 1. 주행거리 컬럼의 Nan 데이터를 0으로 변환하기

# %%
# fillna(0) 를 사용하여 주행거리의 Nan 값을 0으로 채워주세요 
df['주행거리'] = df['주행거리'].fillna(0)

# %%
# 데이터프레임 확인
df
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주         연비
# 0   s1  400.0   25.0  sedan  수원  배승식  16.000000
# 1   s2  480.0   24.0  sedan  서울  이주성  20.000000
# 2   v1  465.0   24.0    suv  화성  김민희  19.375000
# 3   c1  340.0   19.0  coupe  서울  김주희  17.894737
# 4   c2    0.0    NaN  coupe  수원  이수연        NaN
# 5   v2    0.0   29.0    suv  광주  황현정        NaN
# 6   s3  490.0   26.0  sedan  고양  신현지  18.846154
# 7   v3  400.0    NaN    suv  광주  최가은        NaN
# 8   s4  390.0   21.0  sedan  서울  이수빈  18.571429

# %% [markdown]
# #### 2. 고객ID 컬럼의 타입을 확인하고 범주형 변수로 바꿔주기

# %%
# dtypes를 사용해서 주행거리 컬럼의 타입을 확인해주세요
df.dtypes
# Out:
# 고객ID      object
# 주행거리     float64
# 연료사용량    float64
# 차종        object
# 지역        object
# 차주        object
# 연비       float64
# dtype: object

# %%
# astype 을 사용해서 str로 바꿔주세요
df['주행거리'] = df['주행거리'].astype(str)

# %%
# 데이터 타입 재확인
df.dtypes

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:2dfd9f88-520f-47f6-b248-85cdfa8e819f.png)

# %% [markdown]
# ### 4-3) 데이터를 정렬해주세요

# %% [markdown]
# #### 1. 연비 값을 기준으로 내림차순으로 데이터프레임 정렬하기

# %%
# sort_values를 사용, ascending=False, inplace=True 로 설정
df.sort_values(by='연비',ascending=False, inplace=True)

# %%
# 데이터프레임 확인
df
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주         연비
# 1   s2  480.0   24.0  sedan  서울  이주성  20.000000
# 2   v1  465.0   24.0    suv  화성  김민희  19.375000
# 6   s3  490.0   26.0  sedan  고양  신현지  18.846154
# 8   s4  390.0   21.0  sedan  서울  이수빈  18.571429
# 3   c1  340.0   19.0  coupe  서울  김주희  17.894737
# 0   s1  400.0   25.0  sedan  수원  배승식  16.000000
# 4   c2    0.0    NaN  coupe  수원  이수연        NaN
# 5   v2    0.0   29.0    suv  광주  황현정        NaN
# 7   v3  400.0    NaN    suv  광주  최가은        NaN

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:0cd50de4-6163-4c44-9508-a8735c1ffeb7.png)

# %% [markdown]
# #### 2. 인덱스를 기준으로 내림차순 정렬하기

# %%
# 원본 df에는 수정이 일어나지 않도록 해주세요!
df.reindex([8,7,6,5,4,3,2,1])
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주         연비
# 8   s4  390.0   21.0  sedan  서울  이수빈  18.571429
# 7   v3  400.0    NaN    suv  광주  최가은        NaN
# 6   s3  490.0   26.0  sedan  고양  신현지  18.846154
# 5   v2    0.0   29.0    suv  광주  황현정        NaN
# 4   c2    0.0    NaN  coupe  수원  이수연        NaN
# 3   c1  340.0   19.0  coupe  서울  김주희  17.894737
# 2   v1  465.0   24.0    suv  화성  김민희  19.375000
# 1   s2  480.0   24.0  sedan  서울  이주성  20.000000

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:7826a479-961f-495b-9567-168ac4c4b14b.png)

# %% [markdown]
# ### 4-4) 데이터프레임을 합쳐주세요

# %% [markdown]
# #### 1. 형태가 동일한 추가 데이터를 기존 데이터프레임과 합친 df4 만들기

# %%
# 추가 데이터

new_customer_id = ['n1', 'n2', 'n3']
new_total_km = [300, 410, 280]
new_car = ['coupe', 'coupe', 'sedan']
new_local = ['서울', '부산', '서울']
new_owner = ['문유정', '이다빈', '최재완']
efficiency = [17, 20.5, 19.87]

new_data={'고객ID': new_customer_id,
      '주행거리': new_total_km,
      '차종': new_car,
      '지역': new_local,
      '차주': new_owner,
        '연비': efficiency
}

columns = ['고객ID', '주행거리', '차종', '지역', '차주', '연비']


new_df = pd.DataFrame(new_data, columns=columns)

# %%
# concat 을 사용해서 df4 만들기 (밑으로 (행방향으로) 이어붙여주세요!)
df4 = pd.concat([df,new_df], axis=0)

# %%
# 데이터프레임 확인
df4
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주         연비
# 1   s2  480.0   24.0  sedan  서울  이주성  20.000000
# 2   v1  465.0   24.0    suv  화성  김민희  19.375000
# 6   s3  490.0   26.0  sedan  고양  신현지  18.846154
# 8   s4  390.0   21.0  sedan  서울  이수빈  18.571429
# 3   c1  340.0   19.0  coupe  서울  김주희  17.894737
# 0   s1  400.0   25.0  sedan  수원  배승식  16.000000
# 4   c2    0.0    NaN  coupe  수원  이수연        NaN
# 5   v2    0.0   29.0    suv  광주  황현정        NaN
# 7   v3  400.0    NaN    suv  광주  최가은        NaN
# 0   n1    300    NaN  coupe  서울  문유정  17.000000
# 1   n2    410    NaN  coupe  부산  이다빈  20.500000
# 2   n3    280    NaN  sedan  서울  최재완  19.870000

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:d5145988-ef13-4196-944f-87f8f904b71a.png)

# %% [markdown]
# #### 2. 형태가 다른 데이터프레임을 합쳐 df5 만들기

# %%
# 추가 데이터

new2_customer_id = ['n5', 'n6', 'n7']
new2_car = ['sedan', 'coupe', 'suv']
new2_owner = ['조영진', '김진형', '연동운']
new2_efficiency = [17.76, 21, 19.5]
color = ['red', 'green', 'blue']


new_data2={'고객ID': new2_customer_id,
      '차종': new2_car,
      '차주': new2_owner,
          '연비': new2_efficiency,
           '도색': color
}

columns = ['고객ID', '차종', '차주', '연비', '도색']


new2_df = pd.DataFrame(new_data2, columns=columns)

# %%
# merge를 사용해서 df5 만들기, how=outer 설정

df5 = pd.merge(df,new2_df, how='outer', on=['고객ID', '차종', '차주', '연비'])

# %%
# 데이터프레임 확인

df5
# Out:
#    고객ID   주행거리  연료사용량     차종   지역   차주         연비     도색
# 0    c1  340.0   19.0  coupe   서울  김주희  17.894737    NaN
# 1    c2    0.0    NaN  coupe   수원  이수연        NaN    NaN
# 2    n5    NaN    NaN  sedan  NaN  조영진  17.760000    red
# 3    n6    NaN    NaN  coupe  NaN  김진형  21.000000  green
# 4    n7    NaN    NaN    suv  NaN  연동운  19.500000   blue
# 5    s1  400.0   25.0  sedan   수원  배승식  16.000000    NaN
# 6    s2  480.0   24.0  sedan   서울  이주성  20.000000    NaN
# 7    s3  490.0   26.0  sedan   고양  신현지  18.846154    NaN
# 8    s4  390.0   21.0  sedan   서울  이수빈  18.571429    NaN
# 9    v1  465.0   24.0    suv   화성  김민희  19.375000    NaN
# 10   v2    0.0   29.0    suv   광주  황현정        NaN    NaN
# 11   v3  400.0    NaN    suv   광주  최가은        NaN    NaN

# %% [markdown]
# 아래 그림이 나오면 됩니다.
#
# ![image.png](attachment:14ac2860-276b-4165-94bf-32d1cf259397.png)

# %% [markdown]
# # 5. 집계함수 연산

# %% [markdown]
# ### 5-1) 다양한 연산메소드를 사용하여 다음의 문제를 해결해주세요

# %% [markdown]
# #### 1. 연비의 평균 구하기

# %%
# mean 메소드 사용
df['연비'].mean()
# Out:
# 18.44788654328128

# %% [markdown]
# 정답: 18.44788654328128

# %% [markdown]
# #### 2. 연비의 중앙값 구하기

# %%
# median 메소드 사용
df['연비'].median()
# Out:
# 18.70879120879121

# %% [markdown]
# 정답: 18.70879120879121

# %% [markdown]
# #### 3. 연비의 최대값과 최소값 구하기

# %%
# max, min 사용
연비최대값=df['연비'].max()
연비최소값=df['연비'].min()
print('연비최대값:',연비최대값, '연비최소값:',연비최소값)
# Out:
# 연비최대값: 20.0 연비최소값: 16.0

# %% [markdown]
# 연비최대값: 20.0 연비최소값: 16.0

# %% [markdown]
# ### 5-2) groupby 메소드를 사용하여 문제를 해결해주세요

# %% [markdown]
# #### 1. 차종 별 연비의 평균 확인하기

# %%
# groupby 와 mean 메소드를 사용해주세요
df.groupby('차종')['연비'].mean()
# Out:
# 차종
# coupe    17.894737
# sedan    18.354396
# suv      19.375000
# Name: 연비, dtype: float64

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:d07de1df-93da-493a-8803-b8325970f97a.png)

# %% [markdown]
# #### 2. 지역 별로 차주는 누가 있는지 확인하기

# %%
# groupby 와 unique 메소드를 사용해주세요
df.groupby('지역')['차주'].unique()
# Out:
# 지역
# 고양              [신현지]
# 광주         [황현정, 최가은]
# 서울    [이주성, 이수빈, 김주희]
# 수원         [배승식, 이수연]
# 화성              [김민희]
# Name: 차주, dtype: object

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:d436e7d8-273f-4240-a294-16b115ed1357.png)

# %% [markdown]
# #### 3. 지역 별로 차종 별 개수 확인하기

# %%
# groupby 와 value_counts 메소드를 사용해주세요
df.groupby('지역')['차종'].count()
# Out:
# 지역
# 고양    1
# 광주    2
# 서울    3
# 수원    2
# 화성    1
# Name: 차종, dtype: int64

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:c4087024-72cd-4ff9-9b21-f6d4307dcf2d.png)

# %% [markdown]
# 실습 진행하시느라 고생 많았습니다!! ^^

# %% [markdown]
# ### +) 심심하신 분들을 위한 추가 문제

# %%
df
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주         연비
# 1   s2  480.0   24.0  sedan  서울  이주성  20.000000
# 2   v1  465.0   24.0    suv  화성  김민희  19.375000
# 6   s3  490.0   26.0  sedan  고양  신현지  18.846154
# 8   s4  390.0   21.0  sedan  서울  이수빈  18.571429
# 3   c1  340.0   19.0  coupe  서울  김주희  17.894737
# 0   s1  400.0   25.0  sedan  수원  배승식  16.000000
# 4   c2    0.0    NaN  coupe  수원  이수연        NaN
# 5   v2    0.0   29.0    suv  광주  황현정        NaN
# 7   v3  400.0    NaN    suv  광주  최가은        NaN

# %% [markdown]
# #### 1. 세번째, 첫번째, 여섯번째, 다섯번째의 데이터를 추출해 데이터프레임의 형태로 dfdf에 저장하는 한줄코드를 작성해주세요!

# %%
dfdf = df.iloc[[2,0,5,4]]

# %%
# 데이터프레임 확인
dfdf

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:589afb4a-d88a-4479-b948-99b43a06f031.png)

# %% [markdown]
# #### 2. dfdf 원본의 인덱스를 초기화시키는 한줄코드를 작성해주세요! (컬럼이 새로 생성되지 않도록 주의해주세요)

# %%
dfdf.reset_index(inplace = True, drop = True)

# %%
# 데이터프레임 확인
dfdf

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:44d993c4-9052-455d-a0be-0b2014558efa.png)

# %% [markdown]
# #### 3. loc 방식을 사용하여 dfdf의 행에 대해 주행거리와 연비를 더한 값을 Series의 형태로 반환해주세요! (만약 error가 발생한다면, 데이터의 타입을 확인하고 적절하게 변경해주세요!)

# %%
dfdf.loc[:, '주행거리'] = dfdf['주행거리'].astype('float') 
# dfdf.loc['주행거리'] = dfdf['주행거리'].astype('float')로 작성시 경고메세지가 뜰 수 있습니다.
# 대충 원본을 실수로 수정할까봐 조심하라고 뜨는건데 이때 loc을 통해 인덱싱을 한다는 건 원본을 수정하려는 의도가 맞으니 걱정하지 말라는 느낌입니다.
# 경고메세지랑 별개로 코드 자체에는 큰 문제는 없으니 신경쓰지 말라고 전해주세요. (만약 물어본다면)
dfdf.loc[:, ['주행거리','연비']].sum(axis=1)

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:00c97207-4ed8-4ee0-b0e1-c469c1ddd7a3.png)
